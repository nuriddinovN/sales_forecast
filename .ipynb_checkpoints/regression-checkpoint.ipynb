# %%
# %%capture
# %run pre_process.ipynb
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Linear Prediction'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 2
#       1 #mean squared error
# ----> 2 sqr_err=np.sqrt(mean_squared_error(predict_df["Linear Prediction"],monthly_sales['sales'][-12:]))
#       3 #mean absolute error
#       4 abs_err=mean_absolute_error(predict_df['Linear Prediction'],monthly_sales["sales"][-12:])
#
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Linear Prediction'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Linear Prediction'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 get_ipython().run_line_magic('run', 'pre_process.ipynb')
#
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2456, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2454     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2455 with self.builtin_trap:
# -> 2456     result = fn(*args, **kwargs)
#    2458 # The code below prevents the output from being displayed
#    2459 # when using magics with decorator @output_can_be_silenced
#    2460 # when the last Python token in the expression is a ';'.
#    2461 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/IPython/core/magics/execution.py:737, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     735     with preserve_keys(self.shell.user_ns, '__file__'):
#     736         self.shell.user_ns['__file__'] = filename
# --> 737         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     738     return
#     740 # Control the response to exit() calls made by the script being run
#
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2978, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2976 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2977 if raise_exceptions:
# -> 2978     result.raise_error()
#    2979 elif not result.success:
#    2980     break
#
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:294, in ExecutionResult.raise_error(self)
#     292     raise self.error_before_exec
#     293 if self.error_in_exec is not None:
# --> 294     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# Cell In[30], line 2
#       1 #mean squared error
# ----> 2 sqr_err=np.sqrt(mean_squared_error(predict_df["Linear Prediction"],monthly_sales['sales'][-12:]))
#       3 #mean absolute error
#       4 abs_err=mean_absolute_error(predict_df['Linear Prediction'],monthly_sales["sales"][-12:])
#
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Linear Prediction'

# %% [markdown]
# <h1>Linear Regression Model</h1>

# %%
lr_model=LinearRegression()
lr_model.fit(x_train,y_train)
lr_predict=lr_model.predict(x_test)

# %%
lr_predict=lr_predict.reshape(-1,1)
lr_predict_test=np.concatenate([lr_predict,x_test],axis=1)

lr_predict_test=scaler.inverse_transform(lr_predict_test)

# %%
result=[]
for i in range(0,len(lr_predict_test)):
    result.append(lr_predict_test[i][0]+actual_sales[i])
lr_predict_series=pd.Series(result,name="Linear Prediction")
predict_df=predict_df.merge(lr_predict_series,left_index=True,right_index=True)
print(predict_df)
# Out:
#          date  Linear Prediction_x  Linear Prediction_y
# 0  2017-01-01         6.479148e+05         6.479148e+05
# 1  2017-02-01         6.283374e+05         6.283374e+05
# 2  2017-03-01         8.195190e+05         8.195190e+05
# 3  2017-04-01         9.436391e+05         9.436391e+05
# 4  2017-05-01         1.033653e+06         1.033653e+06
# 5  2017-06-01         1.065286e+06         1.065286e+06
# 6  2017-07-01         1.201561e+06         1.201561e+06
# 7  2017-08-01         1.002123e+06         1.002123e+06
# 8  2017-09-01         9.415142e+05         9.415142e+05
# 9  2017-10-01         9.080646e+05         9.080646e+05
# 10 2017-11-01         9.167461e+05         9.167461e+05
# 11 2017-12-01         6.947978e+05         6.947978e+05

# %% [markdown]
# <h1>Errors</h1>

# %%
#mean squared error
sqr_err=np.sqrt(mean_squared_error(predict_df["Linear Prediction"],monthly_sales['sales'][-12:]))
#mean absolute error
abs_err=mean_absolute_error(predict_df['Linear Prediction'],monthly_sales["sales"][-12:])
#r2_score
r2=re_score=(predict_df['Linear Prediction'],monthly_sales['sales'][-12:])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Linear Prediction'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 2
#       1 #mean squared error
# ----> 2 sqr_err=np.sqrt(mean_squared_error(predict_df["Linear Prediction"],monthly_sales['sales'][-12:]))
#       3 #mean absolute error
#       4 abs_err=mean_absolute_error(predict_df['Linear Prediction'],monthly_sales["sales"][-12:])
#
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Linear Prediction'

# %%
print(f'mean squared error: {sqr_err}\n absolute error: {abs_err}\nr2 score: \n{r2}')
# Out:
# mean squared error: 16221.272385416887
#  absolute error: 12433.184266490765
# r2 score:
# (0     6.479148e+05
# 1     6.283374e+05
# 2     8.195190e+05
# 3     9.436391e+05
# 4     1.033653e+06
# 5     1.065286e+06
# 6     1.201561e+06
# 7     1.002123e+06
# 8     9.415142e+05
# 9     9.080646e+05
# 10    9.167461e+05
# 11    6.947978e+05
# Name: Linear Prediction, dtype: float64, 48     617306
# 49     621369
# 50     822667
# 51     938862
# 52    1020686
# 53    1064624
# 54    1171393
# 55    1026403
# 56     935263
# 57     891160
# 58     928837
# 59     695170
# Name: sales, dtype: int64)

# %% [markdown]
# <h1>Plotting</h1>

# %%
plt.figure(figsize=(15,7))
plt.plot(monthly_sales['date'],monthly_sales['sales'])
plt.plot(predict_df['date'],predict_df['Linear Prediction'])
plt.title('Custumer sales forecast using LR model')
plt.xlabel("Date")
plt.ylabel('Sales')
plt.legend(["actual sales",'predicted sales'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Linear Prediction'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 3
#       1 plt.figure(figsize=(15,7))
#       2 plt.plot(monthly_sales['date'],monthly_sales['sales'])
# ----> 3 plt.plot(predict_df['date'],predict_df['Linear Prediction'])
#       4 plt.title('Custumer sales forecast using LR model')
#       5 plt.xlabel("Date")
#
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Linear Prediction'
